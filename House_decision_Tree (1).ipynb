# %%
#Import the libraries
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load the data
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-36c51c19-9d49-4d07-a8d0-c8a6f02b163e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36c51c19-9d49-4d07-a8d0-c8a6f02b163e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving melb_data.csv to melb_data (1).csv
# ...

# %%
#Store the data
df=pd.read_csv('melb_data.csv')
df
# Out:
#               Suburb  ... Propertycount
# 0         Abbotsford  ...        4019.0
# 1         Abbotsford  ...        4019.0
# 2         Abbotsford  ...        4019.0
# 3         Abbotsford  ...        4019.0
# 4         Abbotsford  ...        4019.0
# ...              ...  ...           ...
# 13575  Wheelers Hill  ...        7392.0
# 13576   Williamstown  ...        6380.0
# 13577   Williamstown  ...        6380.0
# 13578   Williamstown  ...        6380.0
# 13579     Yarraville  ...        6543.0
#
# [13580 rows x 21 columns]

# %%
#2D Seaborn KDE plot
import seaborn as sns
sns.jointplot(x=df['Bathroom'], y=df['Price'], kind="kde")
sns.set(rc={'figure.figsize':(15,10)})

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,15))
sns.jointplot(x=df['Propertycount'], y=df['Price'], kind="reg", color='green')

# %%
sns.set(style="whitegrid")
ax=sns.boxplot(x="Bedroom2", y="Price", data=df, hue="Bathroom")

# %%
df.corr()
# Out:
#                   Rooms     Price  ...  Longtitude  Propertycount
# Rooms          1.000000  0.496634  ...    0.100771      -0.081530
# Price          0.496634  1.000000  ...    0.203656      -0.042153
# Distance       0.294203 -0.162522  ...    0.239425      -0.054910
# Postcode       0.055303  0.107867  ...    0.445357       0.062304
# Bedroom2       0.944190  0.475951  ...    0.102238      -0.081350
# Bathroom       0.592934  0.467038  ...    0.118971      -0.052201
# Car            0.408483  0.238979  ...    0.063395      -0.024295
# Landsize       0.025678  0.037507  ...    0.010833      -0.006854
# BuildingArea   0.124127  0.090981  ...   -0.023810      -0.028840
# YearBuilt     -0.065413 -0.323617  ...   -0.003470       0.006361
# Lattitude      0.015948 -0.212934  ...   -0.357634       0.047086
# Longtitude     0.100771  0.203656  ...    1.000000       0.065988
# Propertycount -0.081530 -0.042153  ...    0.065988       1.000000
#
# [13 rows x 13 columns]

# %%
sns.heatmap(df.corr(), cmap='RdBu', annot=True)

# %%
df.shape
# Out:
# (13580, 21)

# %%
df.describe()
# Out:
#               Rooms         Price  ...    Longtitude  Propertycount
# count  13580.000000  1.358000e+04  ...  13580.000000   13580.000000
# mean       2.937997  1.075684e+06  ...    144.995216    7454.417378
# std        0.955748  6.393107e+05  ...      0.103916    4378.581772
# min        1.000000  8.500000e+04  ...    144.431810     249.000000
# 25%        2.000000  6.500000e+05  ...    144.929600    4380.000000
# 50%        3.000000  9.030000e+05  ...    145.000100    6555.000000
# 75%        3.000000  1.330000e+06  ...    145.058305   10331.000000
# max       10.000000  9.000000e+06  ...    145.526350   21650.000000
#
# [8 rows x 13 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               Suburb  ... Propertycount
# 0         Abbotsford  ...        4019.0
# 1         Abbotsford  ...        4019.0
# 2         Abbotsford  ...        4019.0
# 3         Abbotsford  ...        4019.0
# 4         Abbotsford  ...        4019.0
# ...              ...  ...           ...
# 13575  Wheelers Hill  ...        7392.0
# 13576   Williamstown  ...        6380.0
# 13577   Williamstown  ...        6380.0
# 13578   Williamstown  ...        6380.0
# 13579     Yarraville  ...        6543.0
#
# [13580 rows x 21 columns]>

# %%
df.head(10)
# Out:
#        Suburb             Address  ...             Regionname Propertycount
# 0  Abbotsford        85 Turner St  ...  Northern Metropolitan        4019.0
# 1  Abbotsford     25 Bloomburg St  ...  Northern Metropolitan        4019.0
# 2  Abbotsford        5 Charles St  ...  Northern Metropolitan        4019.0
# 3  Abbotsford    40 Federation La  ...  Northern Metropolitan        4019.0
# 4  Abbotsford         55a Park St  ...  Northern Metropolitan        4019.0
# 5  Abbotsford      129 Charles St  ...  Northern Metropolitan        4019.0
# 6  Abbotsford        124 Yarra St  ...  Northern Metropolitan        4019.0
# 7  Abbotsford       98 Charles St  ...  Northern Metropolitan        4019.0
# 8  Abbotsford  6/241 Nicholson St  ...  Northern Metropolitan        4019.0
# 9  Abbotsford       10 Valiant St  ...  Northern Metropolitan        4019.0
#
# [10 rows x 21 columns]

# %%
df.tail(10)
# Out:
#                Suburb        Address  ...                  Regionname Propertycount
# 13570  Wantirna South  34 Fewster Dr  ...        Eastern Metropolitan        7082.0
# 13571  Wantirna South     15 Mara Cl  ...        Eastern Metropolitan        7082.0
# 13572        Watsonia  76 Kenmare St  ...       Northern Metropolitan        2329.0
# 13573        Werribee    5 Nuragi Ct  ...        Western Metropolitan       16166.0
# 13574     Westmeadows     9 Black St  ...       Northern Metropolitan        2474.0
# 13575   Wheelers Hill   12 Strada Cr  ...  South-Eastern Metropolitan        7392.0
# 13576    Williamstown  77 Merrett Dr  ...        Western Metropolitan        6380.0
# 13577    Williamstown    83 Power St  ...        Western Metropolitan        6380.0
# 13578    Williamstown   96 Verdon St  ...        Western Metropolitan        6380.0
# 13579      Yarraville     6 Agnes St  ...        Western Metropolitan        6543.0
#
# [10 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)

# %%
df_feature=['Rooms', 'Distance', 'Bedroom2', 'Bathroom','Car', 'Landsize','BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude', 'Propertycount']
X=df[df_feature]
X
# Out:
#        Rooms  Distance  Bedroom2  ...  Lattitude  Longtitude  Propertycount
# 0          2       2.5       2.0  ...  -37.79960   144.99840         4019.0
# 1          2       2.5       2.0  ...  -37.80790   144.99340         4019.0
# 2          3       2.5       3.0  ...  -37.80930   144.99440         4019.0
# 3          3       2.5       3.0  ...  -37.79690   144.99690         4019.0
# 4          4       2.5       3.0  ...  -37.80720   144.99410         4019.0
# ...      ...       ...       ...  ...        ...         ...            ...
# 13575      4      16.7       4.0  ...  -37.90562   145.16761         7392.0
# 13576      3       6.8       3.0  ...  -37.85927   144.87904         6380.0
# 13577      3       6.8       3.0  ...  -37.85274   144.88738         6380.0
# 13578      4       6.8       4.0  ...  -37.85908   144.89299         6380.0
# 13579      4       6.3       4.0  ...  -37.81188   144.88449         6543.0
#
# [13580 rows x 11 columns]

# %%
y=df.Price
#y=df["Price"]
y
# Out:
# 0        1480000.0
# 1        1035000.0
# 2        1465000.0
# 3         850000.0
# 4        1600000.0
#            ...
# 13575    1245000.0
# 13576    1031000.0
# 13577    1170000.0
# 13578    2500000.0
# 13579    1285000.0
# Name: Price, Length: 13580, dtype: float64

# %%
y.dtype
# Out:
# dtype('float64')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
df.shape
# Out:
# (13580, 21)

# %%
X.shape
# Out:
# (13580, 11)

# %%
y.shape
# Out:
# (13580,)

# %%
y_train.shape
# Out:
# (10864,)

# %%
y_test.shape
# Out:
# (2716,)

# %%
X_train.shape
# Out:
# (10864, 11)

# %%
X_test.shape
# Out:
# (2716, 11)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error as MAE


#Define the model
clf=tree.DecisionTreeRegressor(random_state=1)
#Train the model with train dataset
clf.fit(X_train, y_train)
#Predict by Test dataset
preds=clf.predict(X_test)
erro0=MAE(y_test, preds)
error0
# Out:
# 228718.3796023564

# %%
scores=[]
node_range=range(2, 2000)
for k in node_range:
  model=tree.DecisionTreeRegressor(max_leaf_nodes=k)
  model.fit(X_train, y_train)
  preds=model.predict(X_test)
  erro=MAE(y_test, preds)
  scores.append(erro)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(node_range, scores)
plt.xlabel("Value of node_range")
plt.ylabel("Testing Accuracy")
# Out:
# Text(0, 0.5, 'Testing Accuracy')

# %%
#Define the model
clf=tree.DecisionTreeRegressor(max_leaf_nodes=2000, random_state=1)
#Train the model with train dataset
clf.fit(X_train, y_train)
#Predict by Test dataset
preds=clf.predict(X_test)
erro0=MAE(y_test, preds)
error0
# Out:
# 228718.3796023564

# %%
#Making a function to calculate Mean Absolute Error
def get_mae(max_leaf_nodes, train_X, test_X, train_y, test_y):
  model=DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
  model.fit(train_X, train_y)
  preds_val=model.predict(test_X)
  mae=mae(test_y, preds_val)
  return(mae)

# %%
for max_leaf_nodes in range(1000):
  my_mae=get_mae(max_leaf_nodes, train_X, test_X, train_y, test_y)
  print("Max leaf nodes: %d \t\t Mean Absolute Error: %d" %(max_leaf_nodes, my_mae))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ad3c9c7be1c5> in <module>()
#       1 for max_leaf_nodes in range(1000):
# ----> 2   my_mae=get_mae(max_leaf_nodes, train_X, test_X, train_y, test_y)
#       3   print("Max leaf nodes: %d \t\t Mean Absolute Error: %d" %(max_leaf_nodes, my_mae))
#
# NameError: name 'train_X' is not defined

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
#Build a model
# df_model1 = tree.DecisionTreeClassifier(max_depth=2, random_state=1)
df_model=tree.DecisionTreeClassifier(random_state=1)
#Train the model with train dataset
df_model.fit(X_train, y_train)
#Predict by Test dataset
price_preds=df_model.predict(X_test)
error=MAE(y_test, price_preds)
error
